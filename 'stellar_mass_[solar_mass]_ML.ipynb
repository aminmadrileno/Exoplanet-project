# %%
import pandas  as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import selenium
import feedparser
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import requests as req
from bs4 import BeautifulSoup as bs    # ambos alias son cosa mia
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
def machinelearning(feature):
    global column
    global predictdataraw
    global predictdata
    column = pd.read_csv(f'{feature}_AI_onlyv.csv').drop(['Unnamed: 0'], axis=1)
    predictdataraw = pd.read_csv(f'{feature}_AI_prediction.csv')
    predictdata = pd.read_csv(f'{feature}_AI_prediction.csv').drop(['Unnamed: 0'], axis=1)

# %%
#pon aqui
machinelearning('stellar_mass_[solar_mass]')

# %%
predictdata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   stellar_effective_temperature_[k]  204 non-null    float64
#  1   stellar_radius_[solar_radius]      0 non-null      float64
#  2   stellar_mass_[solar_mass]          204 non-null    float64
#  3   stellar_surface_gravity            8 non-null      float64
# dtypes: float64(4)
# memory usage: 6.5 KB

# %%
#pon aqui 
predictdata.drop(['stellar_mass_[solar_mass]', 'stellar_surface_gravity', 'stellar_radius_[solar_radius]'] ,axis=1, inplace=True)
predictdata.dropna(inplace=True)

# %%
predictdata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 1 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   stellar_effective_temperature_[k]  204 non-null    float64
# dtypes: float64(1)
# memory usage: 1.7 KB

# %%
column.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5042 entries, 0 to 5041
# Data columns (total 4 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   stellar_effective_temperature_[k]  5042 non-null   float64
#  1   stellar_radius_[solar_radius]      5042 non-null   float64
#  2   stellar_mass_[solar_mass]          5042 non-null   float64
#  3   stellar_surface_gravity            5042 non-null   float64
# dtypes: float64(4)
# memory usage: 157.7 KB

# %%
#pon aqui 
X = column.drop(['stellar_radius_[solar_radius]', 'stellar_surface_gravity', 'stellar_mass_[solar_mass]'],axis=1)
y = column['stellar_mass_[solar_mass]']
X
# Out:
#       stellar_effective_temperature_[k]
# 0                                4742.0
# 1                                4213.0
# 2                                4813.0
# 3                                5338.0
# 4                                5750.0
# ...                                 ...
# 5037                             6043.0
# 5038                             5120.0
# 5039                             5120.0
# 5040                             5120.0
# 5041                             5760.0
#
# [5042 rows x 1 columns]

# %%
y
# Out:
# 0       2.70
# 1       2.78
# 2       2.20
# 3       0.91
# 4       1.08
#         ...
# 5037    0.95
# 5038    0.80
# 5039    0.80
# 5040    0.80
# 5041    1.11
# Name: stellar_mass_[solar_mass], Length: 5042, dtype: float64

# %%
def modelexecution(X, y, depth):
    X = StandardScaler().fit_transform(X)
    global y_test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    global model1
    model1 = RandomForestRegressor(n_estimators=200, max_depth=depth, random_state=42)
    model1.fit(X_train, y_train)
    global y_pred_rf
    y_pred_rf = model1.predict(X_test)
    global MSE_RF
    MSE_RF = mean_squared_error(y_test, y_pred_rf, squared=False)
    global model2
    model2 = LinearRegression()
    model2.fit(X_train, y_train)
    global y_pred_lr
    y_pred_lr = model2.predict(X_test)
    global MSE_LR
    MSE_LR = mean_squared_error(y_test, y_pred_lr, squared=False)
    return MSE_LR, MSE_RF, y_test

# %%
modelexecution(X, y, 6)
# Out:
# (0.4149997012606465,
#  0.36119582491848906,
#  4942    0.86
#  1919    1.05
#  1049    0.65
#  4696    1.01
#  3312    1.17
#          ...
#  1507    1.12
#  1033    1.53
#  1097    0.83
#  1469    1.06
#  543     1.05
#  Name: stellar_mass_[solar_mass], Length: 1513, dtype: float64)

# %%
y_test[:10]
# Out:
# 4942    0.86
# 1919    1.05
# 1049    0.65
# 4696    1.01
# 3312    1.17
# 4299    0.98
# 240     0.47
# 4064    1.29
# 2702    1.20
# 239     0.48
# Name: stellar_mass_[solar_mass], dtype: float64

# %%
#pon aqui 
mean = column['stellar_mass_[solar_mass]'].mean()
mean
# Out:
# 0.9765370884569631

# %%
for i in y_pred_rf[:10]:
    print('{:.2f}'.format(i))
# Out:
# 1.09
# 1.12
# 0.93
# 0.99
# 1.19
# 0.97
# 0.48
# 1.19
# 1.12
# 0.41

# %%
final_pred = model1.predict(predictdata)

# %%
for i in final_pred[:]:
    print('{:.2f}'.format(i))
# Out:
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51
# 0.51

# %%
len(final_pred)
# Out:
# 204

# %%
predictdataraw
# Out:
#      Unnamed: 0  stellar_effective_temperature_[k]  \
# 0            12                        5881.482920
# 1            74                         580.500000
# 2            76                        3099.000000
# 3           118                        5792.666141
# 4           170                        2838.000000
# ..          ...                                ...
# 199        2905                        5984.554471
# 200        2906                        5792.666141
# 201        2907                        4570.000000
# 202        2908                        5984.554471
# 203        2909                        5843.748760
#
#      stellar_radius_[solar_radius]  stellar_mass_[solar_mass]  \
# 0                              NaN                       0.19
# 1                              NaN                       0.02
# 2                              NaN                       0.35
# 3                              NaN                       0.07
# 4                              NaN                       0.05
# ..                             ...                        ...
# 199                            NaN                       0.37
# 200                            NaN                       0.08
# 201                            NaN                       0.58
# 202                            NaN                       0.48
# 203                            NaN                       0.14
#
#      stellar_surface_gravity
# 0                        NaN
# 1                       4.72
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 199                      NaN
# 200                      NaN
# 201                      NaN
# 202                      NaN
# 203                      NaN
#
# [204 rows x 5 columns]

# %%
predictdata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 1 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   stellar_effective_temperature_[k]  204 non-null    float64
# dtypes: float64(1)
# memory usage: 1.7 KB

# %%
#pon aqui la mas corta feature
algo = predictdataraw[predictdataraw['stellar_effective_temperature_[k]'].isnull() == True ]
len(algo)
# Out:
# 0

# %%
predictdataraw.drop(algo.index, inplace=True)
predictdataraw['predicted'] = final_pred
predictdataraw
# Out:
#      Unnamed: 0  stellar_effective_temperature_[k]  \
# 0            12                        5881.482920
# 1            74                         580.500000
# 2            76                        3099.000000
# 3           118                        5792.666141
# 4           170                        2838.000000
# ..          ...                                ...
# 199        2905                        5984.554471
# 200        2906                        5792.666141
# 201        2907                        4570.000000
# 202        2908                        5984.554471
# 203        2909                        5843.748760
#
#      stellar_radius_[solar_radius]  stellar_mass_[solar_mass]  \
# 0                              NaN                       0.19
# 1                              NaN                       0.02
# 2                              NaN                       0.35
# 3                              NaN                       0.07
# 4                              NaN                       0.05
# ..                             ...                        ...
# 199                            NaN                       0.37
# 200                            NaN                       0.08
# 201                            NaN                       0.58
# 202                            NaN                       0.48
# 203                            NaN                       0.14
#
#      stellar_surface_gravity  predicted
# 0                        NaN   0.507593
# 1                       4.72   0.507593
# 2                        NaN   0.507593
# 3                        NaN   0.507593
# 4                        NaN   0.507593
# ..                       ...        ...
# 199                      NaN   0.507593
# 200                      NaN   0.507593
# 201                      NaN   0.507593
# 202                      NaN   0.507593
# 203                      NaN   0.507593
#
# [204 rows x 6 columns]

# %%
finaldata = predictdataraw[['Unnamed: 0', 'predicted']]
finaldata
# Out:
#      Unnamed: 0  predicted
# 0            12   0.507593
# 1            74   0.507593
# 2            76   0.507593
# 3           118   0.507593
# 4           170   0.507593
# ..          ...        ...
# 199        2905   0.507593
# 200        2906   0.507593
# 201        2907   0.507593
# 202        2908   0.507593
# 203        2909   0.507593
#
# [204 rows x 2 columns]

# %%
rows = list(finaldata['Unnamed: 0'])
rows2 = list(finaldata['predicted'])
nextdata = pd.read_csv('nextdata.csv')
nextdata
# Out:
#       Unnamed: 0   planet_name   host_name  orbital_period_[days]  \
# 0              0      11 Com b      11 Com             326.030000
# 1              1      11 UMi b      11 UMi             516.219970
# 2              2      14 And b      14 And             185.840000
# 3              3      14 Her b      14 Her            1765.038901
# 4              4    16 Cyg B b    16 Cyg B             798.500000
# ...          ...           ...         ...                    ...
# 5260        5260  Kepler-228 d  Kepler-228              11.094286
# 5261        5261  Kepler-229 b  Kepler-229               6.252972
# 5262        5262  Kepler-229 c  Kepler-229              16.068638
# 5263        5263  Kepler-229 d  Kepler-229              41.194912
# 5264        5264   Kepler-23 b   Kepler-23               7.107300
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 0                        1.290000          12.10   6165.60000       19.100000
# 1                        1.530000          12.30   4684.81420       13.800000
# 2                        0.830000          12.90   1525.50000        3.900000
# 3                        2.773069          12.60   2586.74645        7.110000
# 4                        1.660000          13.50    565.73740        1.260000
# ...                           ...            ...          ...             ...
# 5260                     0.101000           4.04     15.40000        1.280000
# 5261                     0.062000           2.20      5.48000        2.830000
# 5262                     0.117000           4.92     21.50000        0.992000
# 5263                     0.220000           3.85     14.20000        1.370000
# 5264                     0.075000           1.90    254.30000       34.972449
#
#      eccentricity  equilibrium_temperature_[k]  \
# 0        0.231000                   313.321965
# 1        0.080000                   313.321965
# 2        0.000000                   313.321965
# 3        0.372689                   308.484799
# 4        0.680000                   311.602502
# ...           ...                          ...
# 5260     0.000000                   835.000000
# 5261     0.000000                   823.000000
# 5262     0.000000                   600.000000
# 5263     0.000000                   439.000000
# 5264     0.060000                  1157.000000
#
#       ratio_of_semi-major_axis_to_stellar_radius  \
# 0                                      14.599543
# 1                                      11.043941
# 2                                      16.225144
# 3                                     641.181348
# 4                                     315.887759
# ...                                          ...
# 5260                                   10.900000
# 5261                                   18.940000
# 5262                                   36.850000
# 5263                                   70.750000
# 5264                                   10.643000
#
#       stellar_effective_temperature_[k]  stellar_radius_[solar_radius]  \
# 0                                4742.0                          19.00
# 1                                4213.0                          29.79
# 2                                4813.0                          11.00
# 3                                5338.0                           0.93
# 4                                5750.0                           1.13
# ...                                 ...                            ...
# 5260                             6043.0                           1.01
# 5261                             5120.0                           0.73
# 5262                             5120.0                           0.73
# 5263                             5120.0                           0.73
# 5264                             5760.0                           1.52
#
#      stellar_mass_[solar_mass] stellar_metallicity_[dex] distance_[pc]  \
# 0                         2.70                    -0.350    93.1846000
# 1                         2.78                    -0.020   125.3210000
# 2                         2.20                    -0.240    75.4392000
# 3                         0.91                     0.405    17.9323000
# 4                         1.08                     0.060    21.1397000
# ...                        ...                       ...           ...
# 5260                      0.95                    -0.030  1644.6100000
# 5261                      0.80                     0.160   826.2650000
# 5262                      0.80                     0.160   826.2650000
# 5263                      0.80                     0.160   826.2650000
# 5264                      1.11                    -0.090   835.7560000
#
#       number_of_planets insolation_flux_earth stellar_surface_gravity  \
# 0                     1                                          2.31
# 1                     1                                          1.93
# 2                     1                                          2.63
# 3                     2                                          4.45
# 4                     1                                          4.36
# ...                 ...                   ...                     ...
# 5260                  3                122.78                    4.47
# 5261                  3                 76.22                    4.63
# 5262                  3                 21.64                    4.63
# 5263                  3                  6.16                    4.63
# 5264                  3                446.11                    4.00
#
#      stellar_age_[gyr]
# 0
# 1                1.560
# 2                4.500
# 3                3.900
# 4                7.400
# ...                ...
# 5260             0.300
# 5261             1.100
# 5262             1.100
# 5263             1.100
# 5264             6.000
#
# [5265 rows x 20 columns]

# %%
filtered = nextdata[nextdata['Unnamed: 0'].isin(rows)]
filtered
# Out:
#       Unnamed: 0                   planet_name                  host_name  \
# 12            12  2MASS J01033563-5515561 AB b  2MASS J01033563-5515561 A
# 74            74      CFBDSIR J145829+101343 b     CFBDSIR J145829+101343
# 76            76                     CHXR 73 b                    CHXR 73
# 118          118    DENIS-P J082303.1-491201 b   DENIS-P J082303.1-491201
# 170          170                      FU Tau b                     FU Tau
# ...          ...                           ...                        ...
# 2905        2905          KMT-2021-BLG-1391L b         KMT-2021-BLG-1391L
# 2906        2906          KMT-2021-BLG-1554L b         KMT-2021-BLG-1554L
# 2907        2907          KMT-2021-BLG-1689L b         KMT-2021-BLG-1689L
# 2908        2908          KMT-2021-BLG-1898L b         KMT-2021-BLG-1898L
# 2909        2909          KMT-2021-BLG-2294L b         KMT-2021-BLG-2294L
#
#       orbital_period_[days]  orbit_semi-major_axis_[au])  planet_radius  \
# 12              3165.079609                        84.00          12.30
# 74             10037.500000                         2.60          12.40
# 76              3165.079609                       210.00          12.30
# 118              246.360000                         0.36          11.90
# 170             3165.079609                       800.00          12.20
# ...                     ...                          ...            ...
# 2905             182.929938                         2.29           1.97
# 2906              51.527127                         0.72           6.90
# 2907             205.314025                         2.50           7.71
# 2908             145.744019                         1.90          14.00
# 2909              85.210823                         1.15           5.02
#
#       planet_mass  planet_density eccentricity  equilibrium_temperature_[k]  \
# 12     4131.79000          12.200                                       NaN
# 74     3337.10000           9.620                                     370.0
# 76     3994.48600          11.800                                       NaN
# 118    9057.77000          29.500     0.345000                          NaN
# 170    5085.28000          15.400                                    2375.0
# ...           ...             ...          ...                          ...
# 2905      4.55000           3.270                                       NaN
# 2906     38.13941           0.638                                       NaN
# 2907     46.00000           0.552                                       NaN
# 2908    232.01474           0.465                                       NaN
# 2909     22.24799           0.966                                       NaN
#
#       ratio_of_semi-major_axis_to_stellar_radius  \
# 12                                           NaN
# 74                                           NaN
# 76                                           NaN
# 118                                          NaN
# 170                                          NaN
# ...                                          ...
# 2905                                         NaN
# 2906                                         NaN
# 2907                                         NaN
# 2908                                         NaN
# 2909                                         NaN
#
#       stellar_effective_temperature_[k]  stellar_radius_[solar_radius]  \
# 12                          5881.482920                       1.252749
# 74                           580.500000                       1.075348
# 76                          3099.000000                       1.296071
# 118                         5792.666141                       1.077131
# 170                         2838.000000                       1.077131
# ...                                 ...                            ...
# 2905                        5984.554471                       1.298205
# 2906                        5792.666141                       1.077131
# 2907                        4570.000000                       1.339965
# 2908                        5984.554471                       1.321080
# 2909                        5843.748760                       1.166636
#
#      stellar_mass_[solar_mass] stellar_metallicity_[dex] distance_[pc]  \
# 12                        0.19                              47.2000000
# 74                        0.02                              23.1000000
# 76                        0.35                             190.3740000
# 118                       0.07                              20.7700000
# 170                       0.05                             133.4950466
# ...                        ...                       ...           ...
# 2905                      0.37                            5720.0000000
# 2906                      0.08                            7680.0000000
# 2907                      0.58                            7200.0000000
# 2908                      0.48                            6900.0000000
# 2909                      0.14                            6800.0000000
#
#       number_of_planets insolation_flux_earth stellar_surface_gravity  \
# 12                    1
# 74                    1                                          4.72
# 76                    1
# 118                   1
# 170                   1
# ...                 ...                   ...                     ...
# 2905                  1
# 2906                  1
# 2907                  1
# 2908                  1
# 2909                  1
#
#      stellar_age_[gyr]
# 12               0.030
# 74
# 76               0.002
# 118              1.000
# 170              0.001
# ...                ...
# 2905
# 2906
# 2907
# 2908
# 2909
#
# [204 rows x 20 columns]

# %%
#pon aqui 
nextdata.loc[filtered.index, 'stellar_mass_[solar_mass]'] = rows2
nextdata['stellar_mass_[solar_mass]'] = nextdata['stellar_mass_[solar_mass]'].replace(' ', np.nan)
nextdata['stellar_mass_[solar_mass]'] = nextdata['stellar_mass_[solar_mass]'].astype(float)

# %%
nextdata.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5265 entries, 0 to 5264
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  5265 non-null   int64
#  1   planet_name                                 5265 non-null   object
#  2   host_name                                   5265 non-null   object
#  3   orbital_period_[days]                       5261 non-null   float64
#  4   orbit_semi-major_axis_[au])                 5076 non-null   float64
#  5   planet_radius                               5260 non-null   float64
#  6   planet_mass                                 5260 non-null   float64
#  7   planet_density                              5234 non-null   float64
#  8   eccentricity                                5265 non-null   object
#  9   equilibrium_temperature_[k]                 4867 non-null   float64
#  10  ratio_of_semi-major_axis_to_stellar_radius  4993 non-null   float64
#  11  stellar_effective_temperature_[k]           5265 non-null   float64
#  12  stellar_radius_[solar_radius]               5265 non-null   float64
#  13  stellar_mass_[solar_mass]                   5261 non-null   float64
#  14  stellar_metallicity_[dex]                   5265 non-null   object
#  15  distance_[pc]                               5265 non-null   object
#  16  number_of_planets                           5265 non-null   int64
#  17  insolation_flux_earth                       5265 non-null   object
#  18  stellar_surface_gravity                     5265 non-null   object
#  19  stellar_age_[gyr]                           5265 non-null   object
# dtypes: float64(10), int64(2), object(8)
# memory usage: 3.1 MB

# %%
nextdata.drop(['Unnamed: 0'], axis=1, inplace=True)
nextdata.to_csv('nextdata.csv')

# %%
#pon aqui
nextdata.to_csv('stellar_mass_[solar_mass]_backup.csv')
