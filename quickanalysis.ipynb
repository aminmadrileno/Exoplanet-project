# %%
import pandas  as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
analyze = pd.read_csv('REALdata.csv')

# %%
analyze = analyze.drop(columns=['Unnamed: 0'])

# %%
analyze
# Out:
#        planet_name   host_name  orbital_period_[days]  \
# 0         11 Com b      11 Com             326.030000
# 1         11 UMi b      11 UMi             516.219970
# 2         14 And b      14 And             185.840000
# 3         14 Her b      14 Her            1765.038901
# 4       16 Cyg B b    16 Cyg B             798.500000
# ...            ...         ...                    ...
# 5260  Kepler-228 d  Kepler-228              11.094286
# 5261  Kepler-229 b  Kepler-229               6.252972
# 5262  Kepler-229 c  Kepler-229              16.068638
# 5263  Kepler-229 d  Kepler-229              41.194912
# 5264   Kepler-23 b   Kepler-23               7.107300
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 0                        1.290000          12.10   6165.60000          19.100
# 1                        1.530000          12.30   4684.81420          13.800
# 2                        0.830000          12.90   1525.50000           3.900
# ...

# %%
analyze['Datetest'] = analyze['planet_radius'].str[:2]
analyze['datatest2'] = analyze['planet_mass'].str[:2]
analyze['datatest3'] = analyze['equilibrium_temperature_[k]'].str[0]
# crea una variable que guarda las filas que tienen '1' en la columna 'Datetest' y '1' en la columna 'datatest2' como condicion
algo = analyze[(analyze['Datetest'] == '1.') & (analyze['datatest2'] == '1.') & (analyze['datatest3'] == '2')]
print(len(algo))
algo
# Out:
# 14
#         planet_name    host_name orbital_period_[days]  \
# 174       GJ 1002 b      GJ 1002           10.34650000
# 1179    Wolf 1069 b    Wolf 1069           15.56400000
# 1398   TRAPPIST-1 f   TRAPPIST-1            9.20754000
# 1425      TOI-700 d      TOI-700           37.42396000
# 1438      TOI-561 b      TOI-561            0.44657800
# 1662  Proxima Cen b  Proxima Cen           11.18680000
# 1949   Kepler-929 b   Kepler-929            0.92103214
# 2147    Kepler-78 b    Kepler-78            0.35500744
# 2158   Kepler-770 c   Kepler-770            1.47532231
# 3469   Kepler-438 b   Kepler-438           35.23319000
# 4269  Kepler-1288 b  Kepler-1288            2.76122421
# 4599  Kepler-1531 b  Kepler-1531            1.13854338
# 4674  Kepler-1589 b  Kepler-1589            0.99166527
# 4752  Kepler-1649 c  Kepler-1649           19.53527000
#
#      orbit_semi-major_axis_[au]) planet_radius planet_mass planet_density  \
# ...

# %%
analyze['nulltest'] = analyze['planet_name'].str[:12]
algo  = analyze[analyze['nulltest'] == 'TRAPPIST-1 e']
algo
# Out:
#        planet_name   host_name  orbital_period_[days]  \
# 1399  TRAPPIST-1 e  TRAPPIST-1               6.101013
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 1399                      0.02925           0.92        0.692        4.901605
#
#       eccentricity  equilibrium_temperature_[k]  \
# 1399        0.0051                        250.0
#
#       ratio_of_semi-major_axis_to_stellar_radius  \
# 1399                                      52.855
#
#       stellar_effective_temperature_[k]  stellar_radius_[solar_radius]  \
# 1399                             2566.0                           0.12
#
#       stellar_mass_[solar_mass]  distance_[pc]  number_of_planets  \
# 1399                       0.09      12.429889                  7
#
#       insolation_flux_earth  stellar_surface_gravity  stellar_age_[gyr]  \
# 1399                   0.65                     5.24                0.5
#
#           nulltest
# 1399  TRAPPIST-1 e

# %%
euclidean = pd.read_csv('FINAL_ML_con_TIERRA.csv')

# %%
euclidean[euclidean['Unnamed: 0'] == 1662]
# Out:
#       Unnamed: 0    planet_name    host_name  orbital_period_[days]  \
# 1662        1662  Proxima Cen b  Proxima Cen                11.1868
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 1662                      0.04856           1.03         1.07            5.38
#
#       eccentricity  equilibrium_temperature_[k]  \
# 1662          0.02                        234.0
#
#       ratio_of_semi-major_axis_to_stellar_radius  \
# 1662                                   74.585395
#
#       stellar_effective_temperature_[k]  stellar_radius_[solar_radius]  \
# 1662                             2900.0                           0.14
#
#       stellar_mass_[solar_mass]  distance_[pc]  number_of_planets  \
# 1662                       0.12        1.30119                  1
#
#       insolation_flux_earth  stellar_surface_gravity  stellar_age_[gyr]
# 1662                   0.65                     5.16           0.366293

# %%
euclidean_test = euclidean.drop(columns=['orbit_semi-major_axis_[au])', 'insolation_flux_earth', 'orbital_period_[days]', 'Unnamed: 0', 'planet_name', 'host_name', 'ratio_of_semi-major_axis_to_stellar_radius', 'stellar_effective_temperature_[k]', 'stellar_radius_[solar_radius]', 'stellar_mass_[solar_mass]', 'distance_[pc]', 'number_of_planets', 'stellar_surface_gravity', 'stellar_age_[gyr]'])
euclidean_test.dropna(inplace=True)

# %%
euclidean_test.drop('orbital_period_[days]', axis=1, inplace=True)

# %%
euclidean_test.drop('orbital_period_[days]', axis=1, inplace=True)
euclidean_test.drop('orbit_semi-major_axis_[au])', axis=1, inplace=True)
euclidean_test.dropna(inplace=True)
euclidean_test.drop('insolation_flux_earth', axis=1, inplace=True)

# %%
euclidean_test.dropna(inplace=True)

# %%
euclidean_test.drop('insolation_flux_earth', axis=1, inplace=True)

# %%
euclidean_test = euclidean_test.drop(euclidean_test.index[-1])

# %%
euclidean_test.iloc[1582]
# Out:
# planet_radius                    1.03
# planet_mass                      1.07
# planet_density                   5.38
# eccentricity                     0.02
# equilibrium_temperature_[k]    234.00
# Name: 1662, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
standardized_euclidean = scaler.fit_transform(euclidean_test)

# %%
standardized_euclidean
# Out:
# array([[3.54431900e-01, 1.34914140e-01, 1.47832895e-02, 5.10437753e-01,
#         6.95522821e-02],
#        [3.60437185e-01, 1.02511806e-01, 1.06746669e-02, 4.07622872e-01,
#         6.95522821e-02],
#        [3.78453039e-01, 3.33801623e-02, 3.00006977e-03, 3.53151412e-01,
#         6.95522821e-02],
#        ...,
#        [1.06713908e-01, 3.10120537e-04, 1.03878385e-03, 3.53151412e-01,
#         1.00846614e-01],
#        [4.81623829e-02, 5.56395302e-03, 2.70878000e-02, 3.94005007e-01,
#         2.79631474e-01],
#        [2.11386020e-02, 2.12801003e-05, 4.25591293e-03, 3.64522330e-01,
#         5.50298805e-02]])

# %%
earth = standardized_euclidean[-1].reshape(1, -1)

# %%
from sklearn.metrics import euclidean_distances
distances = euclidean_distances(standardized_euclidean, earth)

# %%
len(distances)
# Out:
# 4846

# %%
distances[:15]
# Out:
# array([[0.38845018],
#        [0.35740396],
#        [0.35934412],
#        [0.42831165],
#        [0.58754626],
#        [0.36007986],
#        [0.3555434 ],
#        [0.64395168],
#        [0.38806568],
#        [0.37620561],
#        [0.43002666],
#        [0.46826858],
#        [0.48544391],
#        [0.4363443 ],
#        [0.42945942]])

# %%
min(distances)
# Out:
# array([0.])

# %%
min(distances)
np.argmin(distances)
# Out:
# 4845

# %%
for index, v in enumerate(distances):
    if v in sorted_distances[1]:
        print(index)
# Out:
# 1582

# %%
sorted_distances = np.sort(distances, axis=0)

# %%
sorted_distances
# Out:
# array([[0.        ],
#        [0.00576327],
#        [0.00836267],
#        ...,
#        [1.12305414],
#        [1.154686  ],
#        [1.20464144]])

# %%
closest_planets = [143,
1123,
1320,
1332,
1333,
1334,
1582,
3057,
4335,
4845]

# %%
planets = euclidean_test.iloc[1332]

# %%
planets = planets.index.to_list()

# %%
planets
# Out:
# planet_radius                    1.045000
# planet_mass                      1.039000
# planet_density                   5.022904
# eccentricity                     0.010070
# equilibrium_temperature_[k]    218.000000
# Name: 1398, dtype: float64

# %%
euclidean.iloc[planets]
# Out:
#       Unnamed: 0         planet_name         host_name  orbital_period_[days]  \
# 174          174           GJ 1002 b           GJ 1002              10.346500
# 1179        1179         Wolf 1069 b         Wolf 1069              15.564000
# 1385        1385  Teegarden's Star c  Teegarden's Star              11.409000
# 1398        1398        TRAPPIST-1 f        TRAPPIST-1               9.207540
# 1399        1399        TRAPPIST-1 e        TRAPPIST-1               6.101013
# 1400        1400        TRAPPIST-1 d        TRAPPIST-1               4.049219
# 1662        1662       Proxima Cen b       Proxima Cen              11.186800
# 3469        3469        Kepler-438 b        Kepler-438              35.233190
# 4752        4752       Kepler-1649 c       Kepler-1649              19.535270
# 5265        5265               Earth               Sun             365.250000
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# ...

# %%
EPIC 206042996 b
ups And d
WASP-150 b
WASP-138 b
WASP-136 b
WASP-135 b
TOI-1516 b
Kepler-1076 b
Kepler-1333 b
Kepler-172 d

# %%
euclidean_test
# Out:
#       planet_radius  planet_mass  planet_density  eccentricity  \
# 0             12.10   6165.60000       19.100000      0.231000
# 1             12.30   4684.81420       13.800000      0.080000
# 2             12.90   1525.50000        3.900000      0.000000
# 3             12.60   2586.74645        7.110000      0.372689
# 4             13.50    565.73740        1.260000      0.680000
# ...             ...          ...             ...           ...
# 5261           2.20      5.48000        2.830000      0.000000
# 5262           4.92     21.50000        0.992000      0.000000
# 5263           3.85     14.20000        1.370000      0.000000
# 5264           1.90    254.30000       34.972449      0.060000
# 5265           1.00      1.00000        5.520000      0.016700
#
#       equilibrium_temperature_[k]
# 0                      313.321965
# 1                      313.321965
# 2                      313.321965
# 3                      308.484799
# ...

# %% [markdown]
# euc

# %%
euclidean_sinml = pd.read_csv('REALdata.csv')

# %%
euclidean_sinml
# Out:
#       Unnamed: 0   planet_name   host_name  orbital_period_[days]  \
# 0              0      11 Com b      11 Com             326.030000
# 1              1      11 UMi b      11 UMi             516.219970
# 2              2      14 And b      14 And             185.840000
# 3              3      14 Her b      14 Her            1765.038901
# 4              4    16 Cyg B b    16 Cyg B             798.500000
# ...          ...           ...         ...                    ...
# 5260        5260  Kepler-228 d  Kepler-228              11.094286
# 5261        5261  Kepler-229 b  Kepler-229               6.252972
# 5262        5262  Kepler-229 c  Kepler-229              16.068638
# 5263        5263  Kepler-229 d  Kepler-229              41.194912
# 5264        5264   Kepler-23 b   Kepler-23               7.107300
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 0                        1.290000          12.10   6165.60000          19.100
# ...

# %%
euclidean_sinml = euclidean_sinml.drop(columns=['Unnamed: 0'])

# %%
euclidean_sinmltest = euclidean_sinml.drop(columns=['Unnamed: 0', 'insolation_flux_earth', 'orbit_semi-major_axis_[au])', 'orbital_period_[days]', 'planet_name', 'host_name', 'ratio_of_semi-major_axis_to_stellar_radius', 'stellar_effective_temperature_[k]', 'stellar_radius_[solar_radius]', 'stellar_mass_[solar_mass]', 'distance_[pc]', 'number_of_planets', 'stellar_surface_gravity', 'stellar_age_[gyr]'])

# %%
euclidean_sinmltest.drop('orbital_period_[days]', axis=1, inplace=True)
euclidean_sinmltest.drop('orbit_semi-major_axis_[au])', axis=1, inplace=True)
euclidean_sinmltest.dropna(inplace=True)
euclidean_sinmltest.drop('insolation_flux_earth', axis=1, inplace=True)

# %%
euclidean_sinmltest.dropna(inplace=True)

# %%
euclidean_sinmltest
# Out:
#       planet_radius  planet_mass  planet_density  eccentricity  \
# 30            1.875        7.990           6.660         0.050
# 46            4.070       20.120           1.320         0.186
# 73            1.820        3.950           3.600         0.000
# 80           16.700      327.350           0.380         0.000
# 83           16.140      291.438           0.411         0.070
# ...             ...          ...             ...           ...
# 5259          2.700        7.750           2.160         0.000
# 5260          4.040       15.400           1.280         0.000
# 5261          2.200        5.480           2.830         0.000
# 5262          4.920       21.500           0.992         0.000
# 5263          3.850       14.200           1.370         0.000
#
#       equilibrium_temperature_[k]
# 30                         1958.0
# 46                          593.0
# 73                          464.0
# 80                         1898.0
# ...

# %%
standard_sinml = scaler.fit_transform(euclidean_sinmltest)

# %%
distances_sinml = euclidean_distances(standard_sinml, earth)

# %%
distances_sinml
# Out:
# array([[0.52104472],
#        [0.22706295],
#        [0.36918804],
#        ...,
#        [0.39137356],
#        [0.4120072 ],
#        [0.38891604]])

# %%
print(min(distances))
np.argmin(distances)
# Out:
# [0.]
# 4845

# %%
sorted_sinml = np.sort(distances_sinml, axis=0)

# %%
for index, v in enumerate(distances_sinml):
    if v in sorted_sinml[:10]:
        print(index)
# Out:
# 231
# 733
# 1695
# 1703
# 2029
# 2030
# 2031
# 2032
# 2033
# 2517

# %%
sorted_sinml
# Out:
# array([[0.0333    ],
#        [0.04531435],
#        [0.05102157],
#        ...,
#        [1.22993271],
#        [1.34061335],
#        [1.36560405]])

# %%
toptenindex = [231,
733,
1695,
1703,
2029,
2030,
2031,
2032,
2033,
2517]

# %%
planets = euclidean_sinmltest.iloc[toptenindex]

# %%
planets = planets.index.to_list()

# %%
planets
# Out:
# [912, 1895, 3458, 3466, 3813, 3814, 3815, 3816, 3817, 4312]

# %%
euclidean_sinml.iloc[planets]
# Out:
#         planet_name    host_name  orbital_period_[days]  \
# 912     HD 238090 b    HD 238090              13.671000
# 1895   Kepler-970 b   Kepler-970              16.736525
# 3458   Kepler-444 f   Kepler-444               9.740486
# 3466   Kepler-440 b   Kepler-440             101.111410
# 3813   Kepler-296 f   Kepler-296              63.336270
# 3814   Kepler-296 e   Kepler-296              34.142110
# 3815   Kepler-296 d   Kepler-296              19.850291
# 3816   Kepler-296 c   Kepler-296               5.841637
# 3817   Kepler-296 b   Kepler-296              10.864384
# 4312  Kepler-1319 b  Kepler-1319               2.886763
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 912                        0.0932          2.520        6.890            2.37
# 1895                       0.1390          2.609        7.310            2.26
# 3458                       0.0811          0.741        0.332            4.48
# ...

# %%
euclidean_test
# Out:
#       planet_radius  planet_mass  planet_density  eccentricity  \
# 0             12.10   6165.60000       19.100000      0.231000
# 1             12.30   4684.81420       13.800000      0.080000
# 2             12.90   1525.50000        3.900000      0.000000
# 3             12.60   2586.74645        7.110000      0.372689
# 4             13.50    565.73740        1.260000      0.680000
# ...             ...          ...             ...           ...
# 5261           2.20      5.48000        2.830000      0.000000
# 5262           4.92     21.50000        0.992000      0.000000
# 5263           3.85     14.20000        1.370000      0.000000
# 5264           1.90    254.30000       34.972449      0.060000
# 5265           1.00      1.00000        5.520000      0.016700
#
#       equilibrium_temperature_[k]
# 0                      313.321965
# 1                      313.321965
# 2                      313.321965
# 3                      308.484799
# ...

# %%
standardized_euclidean
# Out:
# array([[3.54431900e-01, 1.34914140e-01, 1.47832895e-02, 5.10437753e-01,
#         6.95522821e-02],
#        [3.60437185e-01, 1.02511806e-01, 1.06746669e-02, 4.07622872e-01,
#         6.95522821e-02],
#        [3.78453039e-01, 3.33801623e-02, 3.00006977e-03, 3.53151412e-01,
#         6.95522821e-02],
#        ...,
#        [1.06713908e-01, 3.10120537e-04, 1.03878385e-03, 3.53151412e-01,
#         1.00846614e-01],
#        [4.81623829e-02, 5.56395302e-03, 2.70878000e-02, 3.94005007e-01,
#         2.79631474e-01],
#        [2.11386020e-02, 2.12801003e-05, 4.25591293e-03, 3.64522330e-01,
#         5.50298805e-02]])

# %%
standard_amin = pd.DataFrame(standardized_euclidean, columns=euclidean_test.columns)

# %%
standard_amin
# Out:
#       planet_radius  planet_mass  planet_density  eccentricity  \
# 0          0.354432     0.134914        0.014783      0.510438
# 1          0.360437     0.102512        0.010675      0.407623
# 2          0.378453     0.033380        0.003000      0.353151
# 3          0.369445     0.056602        0.005488      0.606913
# 4          0.396469     0.012379        0.000954      0.816159
# ...             ...          ...             ...           ...
# 4841       0.057170     0.000119        0.002171      0.353151
# 4842       0.138842     0.000470        0.000746      0.353151
# 4843       0.106714     0.000310        0.001039      0.353151
# 4844       0.048162     0.005564        0.027088      0.394005
# 4845       0.021139     0.000021        0.004256      0.364522
#
#       equilibrium_temperature_[k]
# 0                        0.069552
# 1                        0.069552
# 2                        0.069552
# 3                        0.068348
# ...

# %%
euclidean_sinml
# Out:
#        planet_name   host_name  orbital_period_[days]  \
# 0         11 Com b      11 Com             326.030000
# 1         11 UMi b      11 UMi             516.219970
# 2         14 And b      14 And             185.840000
# 3         14 Her b      14 Her            1765.038901
# 4       16 Cyg B b    16 Cyg B             798.500000
# ...            ...         ...                    ...
# 5260  Kepler-228 d  Kepler-228              11.094286
# 5261  Kepler-229 b  Kepler-229               6.252972
# 5262  Kepler-229 c  Kepler-229              16.068638
# 5263  Kepler-229 d  Kepler-229              41.194912
# 5264   Kepler-23 b   Kepler-23               7.107300
#
#       orbit_semi-major_axis_[au])  planet_radius  planet_mass  planet_density  \
# 0                        1.290000          12.10   6165.60000          19.100
# 1                        1.530000          12.30   4684.81420          13.800
# 2                        0.830000          12.90   1525.50000           3.900
# ...

# %%
euclidean_sinmltest
# Out:
#       planet_radius  planet_mass  planet_density  eccentricity  \
# 30            1.875        7.990           6.660         0.050
# 46            4.070       20.120           1.320         0.186
# 73            1.820        3.950           3.600         0.000
# 80           16.700      327.350           0.380         0.000
# 83           16.140      291.438           0.411         0.070
# ...             ...          ...             ...           ...
# 5259          2.700        7.750           2.160         0.000
# 5260          4.040       15.400           1.280         0.000
# 5261          2.200        5.480           2.830         0.000
# 5262          4.920       21.500           0.992         0.000
# 5263          3.850       14.200           1.370         0.000
#
#       equilibrium_temperature_[k]
# 30                         1958.0
# 46                          593.0
# 73                          464.0
# 80                         1898.0
# ...

# %%
standard_nasa = pd.DataFrame(standard_sinml, columns=euclidean_sinmltest.columns)

# %%
standard_nasa
# Out:
#       planet_radius  planet_mass  planet_density  eccentricity  \
# 0          0.067934     0.000174        0.005140      0.054142
# 1          0.162371     0.000439        0.001000      0.201407
# 2          0.065568     0.000086        0.002768      0.000000
# 3          0.705761     0.007162        0.000271      0.000000
# 4          0.681668     0.006376        0.000295      0.075799
# ...             ...          ...             ...           ...
# 3452       0.103429     0.000169        0.001651      0.000000
# 3453       0.161081     0.000336        0.000969      0.000000
# 3454       0.081917     0.000119        0.002171      0.000000
# 3455       0.198942     0.000470        0.000746      0.000000
# 3456       0.152906     0.000310        0.001039      0.000000
#
#       equilibrium_temperature_[k]
# 0                        0.470916
# 1                        0.125695
# 2                        0.093070
# 3                        0.455741
# ...
